# %%
from dao.BaseDao import BaseDao

# 职位数据管理数据库操作类   DAO：database access object
class BookDao(BaseDao):

    # Book salary
    def getBooks(self):
        sql = 'select * from book'
        result = self.execute(sql=sql)
        resultSet = self.fetchall()
        return resultSet
    
    # # Book numbers
    # def getBookCountStatisticByBookType(self):
    #     sql = 'select count(Booktype) as nums, Booktype from t_Books group by Booktype'
    #     result = self.execute(sql=sql)
    #     resultSet = self.fetchall()
    #     return resultSet

# %%
bookDao = BookDao()
resultSet = bookDao.getBooks()
print(resultSet[0]['label'])
bookDao.close()
# Out:
# 中国当代文艺

# %%
type(resultSet[0])
# Out:
# dict

# %%
# os.mkdir('finish.flag')
import os
os.path.exists('finish.flag')
# Out:
# False

# %%
os.listdir('./img')
# Out:
# []

# %%
# 职位数据管理数据库操作类   DAO：database access object
class UserDao(BaseDao):

    # user info
    def createUser(self, params=[]):
        id_res = list(self.execute('SELECT id FROM user ORDER BY id DESC LIMIT 1;'))

        sql = "insert into user (id, username, password, uni_id, name, stu_num, pho_num) " \
              "values (%d, %s, %s, %d, %s, %s, %s)"  # %s是占位符
        params = id_res + params
        result = self.execute(sql ,params)
        self.commit()
        return result
    
    def usernameMatch(self, username):
        sql = '''SELECT * FROM `user` where username='{}';'''.format(username)
        self.execute(sql)
        resultSet = self.fetchall()
        return resultSet

# %%
from dao.BaseDao import BaseDao
baseDao = BaseDao()

# %%
res = baseDao.execute('SELECT * FROM user ORDER BY id DESC;')
resSet = baseDao.fetchall()

# %%
for username in resSet:
    print(username['username'])
# Out:
# 23
# tec
# stu
# updated
# admin

# %%
sql = '''SELECT * FROM `user` ''' #where username='{}';'''.format('23')
res = baseDao.execute(sql)
resSet = baseDao.fetchall()
resSet
# Out:
# [{'id': 1,
#   'username': 'admin',
#   'password': '123',
#   'uni_id': 0,
#   'name': 'System',
#   'stu_num': '0',
#   'pho_num': '0',
#   'status': 0},
#  {'id': 3,
#   'username': 'updated',
#   'password': '123',
#   'uni_id': 0,
#   'name': 'name ',
#   'stu_num': '123',
#   'pho_num': '123',
#   'status': 1},
#  {'id': 4,
#   'username': 'stu',
#   'password': '123',
#   'uni_id': 0,
#   'name': 'u',
#   'stu_num': '123',
#   'pho_num': '456',
#   'status': 1},
#  {'id': 5,
#   'username': 'tec',
#   'password': '123',
#   'uni_id': 0,
#   'name': 'user3',
#   'stu_num': '321',
#   'pho_num': '123',
#   'status': 2},
#  {'id': 12,
#   'username': '23',
#   'password': '123',
#   'uni_id': 0,
#   'name': '123',
#   'stu_num': 'undefined',
#   'pho_num': 'undefined',
#   'status': None}]

# %%
print(resSet[3]['name'])
# Out:
# user3
