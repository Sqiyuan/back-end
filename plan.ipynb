# %% [markdown]
# 已完成：
# - 识别索书号并转为ASCII码完成（书标分割出来后在进行图像处理效果更好）
# - 整合进整体流程源代码，完成根据ASCII码比较索书号的功能
# - 将竖直书标回正
# - 保存未识别ASCII码的图片名称（为后期数据库查找做准备）
#
# 未完成：
# - 然后是识别书名，怎么能在书名旁有其他文字时确定书名
# （设想①只要识别的文字在书名中存在即可
# 设想②通过语义模型推理书名）
